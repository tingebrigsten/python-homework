# %%
import pandas as pd
# %matplotlib inline

# %%
from pathlib import Path
csvpath = Path('../Resources/AirPassengers.csv')
df = pd.read_csv(csvpath, parse_dates=True, index_col='Month', infer_datetime_format=True)
df.head()
# Out:
#             NumberPassengers
# Month
# 1949-01-01               112
# 1949-02-01               118
# 1949-03-01               132
# 1949-04-01               129
# 1949-05-01               121

# %%
df['NumberPassengers'].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# # Autocorrelation and Partial Autocorrelation Analysis

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
acfplot =plot_acf(df, lags=20)

# %%
pacfplot = plot_pacf(df, zero=False, lags=20)

# %% [markdown]
# # ARIMA Model

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(df.NumberPassengers, order=(2, 1, 2))
# Out:
# C:\Users\email\Anaconda3\envs\dev\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\email\Anaconda3\envs\dev\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\email\Anaconda3\envs\dev\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
results = model.fit()
# Out:
# C:\Users\email\Anaconda3\envs\dev\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:       NumberPassengers   No. Observations:                  144
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                -671.673
# Date:                Mon, 22 Mar 2021   AIC                           1353.347
# Time:                        12:22:47   BIC                           1368.161
# Sample:                    01-01-1949   HQIC                          1359.366
#                          - 12-01-1960
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.6850      0.020     83.059      0.000       1.645       1.725
# ar.L2         -0.9548      0.017    -55.419      0.000      -0.989      -0.921
# ma.L1         -1.8432      0.125    -14.793      0.000      -2.087      -1.599
# ma.L2          0.9953      0.135      7.372      0.000       0.731       1.260
# sigma2       665.9564    114.129      5.835      0.000     442.268     889.645
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.30   Jarque-Bera (JB):                 1.84
# Prob(Q):                              0.59   Prob(JB):                         0.40
# Heteroskedasticity (H):               7.38   Skew:                             0.27
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Visualize the forecast
pd.DataFrame(results.forecast(steps=3)).plot(title="Passenger Travel Forecast")
# Out:
# <AxesSubplot:title={'center':'Passenger Travel Forecast'}>

# %%
# A second model with a different order
model2 = ARIMA(df['NumberPassengers'], order=(2, 1, 4))
# Out:
# C:\Users\email\Anaconda3\envs\dev\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\email\Anaconda3\envs\dev\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\email\Anaconda3\envs\dev\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
res2 = model2.fit()
# Out:
# C:\Users\email\Anaconda3\envs\dev\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:977: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\email\Anaconda3\envs\dev\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %%
res2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:       NumberPassengers   No. Observations:                  144
# Model:                 ARIMA(2, 1, 4)   Log Likelihood                -674.192
# Date:                Mon, 22 Mar 2021   AIC                           1362.383
# Time:                        12:22:50   BIC                           1383.123
# Sample:                    01-01-1949   HQIC                          1370.811
#                          - 12-01-1960
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1352      0.089     -1.525      0.127      -0.309       0.039
# ar.L2         -0.3603      0.087     -4.128      0.000      -0.531      -0.189
# ma.L1          0.4540      0.076      5.991      0.000       0.305       0.603
# ma.L2          0.2551      0.213      1.200      0.230      -0.162       0.672
# ma.L3         -0.2716      0.070     -3.899      0.000      -0.408      -0.135
# ma.L4         -0.7551      0.184     -4.112      0.000      -1.115      -0.395
# sigma2       738.8888    179.410      4.118      0.000     387.252    1090.525
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 5.46
# Prob(Q):                              0.91   Prob(JB):                         0.07
# Heteroskedasticity (H):               6.95   Skew:                             0.26
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """
